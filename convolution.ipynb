# %%
import matplotlib.pyplot as plt
import torch

x = torch.rand(5, 5)
x
# Out:
# tensor([[0.1737, 0.0864, 0.7208, 0.1078, 0.2247],
#         [0.9075, 0.9224, 0.2864, 0.8809, 0.8962],
#         [0.8302, 0.4800, 0.0548, 0.5603, 0.3566],
#         [0.7977, 0.6903, 0.6834, 0.7975, 0.5214],
#         [0.8946, 0.6576, 0.0884, 0.1559, 0.0073]])

# %%
plt.imshow(x)
plt.show()

# %%
device = torch.device('cuda')

# %%
x.size()
# Out:
# torch.Size([5, 5])

# %%
image_path=".\pic\lenna.png"
pic=plt.imread(image_path)
pic=torch.from_numpy(pic)
pic.size()
# Out:
# torch.Size([512, 512, 3])

# %%
plt.imshow(pic)
plt.show()

# %%
Filter=torch.tensor([[0.5, 1., 0.5],
        [0.5, 1., 0.5],
        [0.5, 1., 0.5]])
for i in range(1,x.size()[0]-1):
    for j in range(1,x.size()[1]-1):  
        print(str(i)+","+str(j))
        sum=0
        for m in range(1,3):
            for n in range(1,3):
                sum+=x[i+m-2,j+m-2]*Filter[m-1,n-1]
        sum/=9
        print(sum)
        x[i,j]=sum
print(x)
# Out:
# 1,1
# tensor(0.1827)
# 1,2
# tensor(0.0621)
# 1,3
# tensor(0.2670)
# 2,1
# tensor(0.2313)
# 2,2
# tensor(0.0396)
# 2,3
# tensor(0.1037)
# 3,1
# tensor(0.2534)
# 3,2
# tensor(0.1525)
# 3,3
# tensor(0.1395)
# tensor([[0.1737, 0.0864, 0.7208, 0.1078, 0.2247],
#         [0.9075, 0.1827, 0.0621, 0.2670, 0.8962],
#         [0.8302, 0.2313, 0.0396, 0.1037, 0.3566],
#         [0.7977, 0.2534, 0.1525, 0.1395, 0.5214],
#         [0.8946, 0.6576, 0.0884, 0.1559, 0.0073]])

# %%
plt.imshow(x)
plt.show()

# %%
Filter=torch.tensor([[0.5, 1., 0.5],
        [0.5, 1., 0.5],
        [0.5, 1., 0.5]])
print(Filter)
#卷积核
for i in range(1,pic.shape[0]-1):
    for j in range(1,pic.shape[1]-1):  
        sum=0
        for m in range(1,3):
            for n in range(1,3):
                sum+=pic[i+m-2,j+m-2]*Filter[m-1,n-1].item()
        sum/=9
        pic[i,j]=sum
print(pic)
# Out:
# tensor([[0.5000, 1.0000, 0.5000],
#         [0.5000, 1.0000, 0.5000],
#         [0.5000, 1.0000, 0.5000]])
# tensor([[[0.8863, 0.5373, 0.4902],
#          [0.8863, 0.5373, 0.4902],
#          [0.8745, 0.5373, 0.5216],
#          ...,
#          [0.9020, 0.5804, 0.4784],
#          [0.8667, 0.5098, 0.4314],
#          [0.7843, 0.3882, 0.3529]],
#
#         [[0.8863, 0.5373, 0.4902],
#          [0.2954, 0.1791, 0.1634],
#          [0.2935, 0.1791, 0.1686],
#          ...,
#          [0.3033, 0.1941, 0.1601],
#          [0.2948, 0.1817, 0.1516],
#          [0.7843, 0.3882, 0.3529]],
#
#         [[0.8863, 0.5373, 0.4902],
#          [0.2954, 0.1791, 0.1634],
#          [0.1950, 0.1194, 0.1142],
#          ...,
#          [0.2010, 0.1290, 0.1069],
#          [0.1950, 0.1173, 0.0986],
#          [0.7843, 0.3882, 0.3529]],
#
#         ...,
#
#         [[0.3294, 0.0706, 0.2353],
#          [0.1111, 0.0268, 0.0784],
#          [0.0796, 0.0235, 0.0516],
#          ...,
#          [0.1347, 0.0564, 0.0655],
#          [0.1345, 0.0534, 0.0601],
#          [0.6941, 0.2431, 0.3098]],
#
#         [[0.3216, 0.0863, 0.2235],
#          [0.1085, 0.0261, 0.0765],
#          [0.0813, 0.0254, 0.0536],
#          ...,
#          [0.1392, 0.0543, 0.0620],
#          [0.1408, 0.0558, 0.0639],
#          [0.7255, 0.2902, 0.3176]],
#
#         [[0.3216, 0.0863, 0.2235],
#          [0.3216, 0.0863, 0.2235],
#          [0.3765, 0.1255, 0.2431],
#          ...,
#          [0.7020, 0.2745, 0.3098],
#          [0.7098, 0.2784, 0.3176],
#          [0.7255, 0.2902, 0.3176]]])

# %%
plt.imshow(pic)
plt.show()
